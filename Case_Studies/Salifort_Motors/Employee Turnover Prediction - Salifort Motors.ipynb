# %% [markdown]
# # <a id='toc1_'></a>[Employee Turnover Prediction - Salifort Motors](#toc0_)
# **Course 7 - Capstone Project**

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [Employee Turnover Prediction - Salifort Motors](#toc1_)
#   - [Scenario](#toc1_1_)
#     - [Data Dictionary](#toc1_1_1_)
#   - [Description and Deliverables](#toc1_2_)
# - [PACE stages](#toc2_)
#   - [PACE: Plan](#toc2_1_)
#     - [Understand the business scenario and problem](#toc2_1_1_)
#     - [Familiarize yourself with the HR dataset](#toc2_1_2_)
#     - [Reflect on these questions as you complete the plan stage.](#toc2_1_3_)
#     - [Step 1. Imports](#toc2_1_4_)
#       - [Import packages](#toc2_1_4_1_)
#     - [Load dataset](#toc2_1_5_)
#     - [Step 2. Data Exploration (Initial EDA and data cleaning)](#toc2_1_6_)
#       - [Gather basic information about the data](#toc2_1_6_1_)
#       - [Gather descriptive statistics about the data](#toc2_1_6_2_)
#       - [Rename columns](#toc2_1_6_3_)
#       - [Check missing values](#toc2_1_6_4_)
#       - [Check duplicates](#toc2_1_6_5_)
#       - [Check outliers](#toc2_1_6_6_)
#   - [PACE: Analyze Stage](#toc2_2_)
#     - [Reflect on these questions as you complete the analyze stage.](#toc2_2_1_)
#     - [Step 2. Data Exploration (Continue EDA)](#toc2_2_2_)
#       - [Data visualizations](#toc2_2_2_1_)
#         - [Satisfaction vs Turnover](#toc2_2_2_1_1_)
#         - [Salary vs Turnover](#toc2_2_2_1_2_)
#         - [Promotion vs Turnover](#toc2_2_2_1_3_)
#         - [Average Monthly Hours vs Number of Projects](#toc2_2_2_1_4_)
#         - [Number of Projects Distribution](#toc2_2_2_1_5_)
#         - [Average Monthly Hours vs Satisfaction](#toc2_2_2_1_6_)
#         - [Satisfaction vs Tenure](#toc2_2_2_1_7_)
#         - [Tenure Distribution](#toc2_2_2_1_8_)
#         - [Salary vs Tenure](#toc2_2_2_1_9_)
#         - [Average Monthly Hours vs Last Evaluation](#toc2_2_2_1_10_)
#         - [Average Monthly Hours vs Promotion](#toc2_2_2_1_11_)
#         - [Department vs Turnover](#toc2_2_2_1_12_)
#         - [Heatmap](#toc2_2_2_1_13_)
#   - [PACE: Construct](#toc2_3_)
#   - [Recall model assumptions](#toc2_4_)
#     - [Reflect on these questions as you complete the constructing stage.](#toc2_4_1_)
#     - [Step 3. Model Building, Step 4. Results and Evaluation](#toc2_4_2_)
#       - [Identify the type of prediction task.](#toc2_4_2_1_)
#       - [Identify the types of models most appropriate for this task.](#toc2_4_2_2_)
#     - [Modeling](#toc2_4_3_)
#       - [Data Preparation](#toc2_4_3_1_)
#       - [Logistic Regression](#toc2_4_3_2_)
#         - [Splitting the Data](#toc2_4_3_2_1_)
#         - [Predictions on the Validation Set](#toc2_4_3_2_2_)
#         - [Confusion Matrix - Validation Set](#toc2_4_3_2_3_)
#         - [Classification Report](#toc2_4_3_2_4_)
#       - [Helper Functions](#toc2_4_3_3_)
#         - [make_results()](#toc2_4_3_3_1_)
#         - [get_results()](#toc2_4_3_3_2_)
#         - [write_pickle()](#toc2_4_3_3_3_)
#         - [read_pickle()](#toc2_4_3_3_4_)
#       - [Decision Tree](#toc2_4_3_4_)
#         - [Splitting the Data](#toc2_4_3_4_1_)
#         - [GridSearchCV Evaluation Metric Results](#toc2_4_3_4_2_)
#         - [Decision Tree - Prediction Performance Scores](#toc2_4_3_4_3_)
#       - [Random Forest](#toc2_4_3_5_)
#         - [Best Parameters](#toc2_4_3_5_1_)
#         - [Best Score](#toc2_4_3_5_2_)
#         - [GridSearchCV Evaluation Metric Results](#toc2_4_3_5_3_)
#         - [Random Forest - Prediction Performance Scores](#toc2_4_3_5_4_)
#       - [XGBoost](#toc2_4_3_6_)
#         - [Best Parameters](#toc2_4_3_6_1_)
#         - [Best Score](#toc2_4_3_6_2_)
#         - [GridSearchCV Evaluation Metric Results](#toc2_4_3_6_3_)
#         - [XGBoost - Prediction Performance Scores](#toc2_4_3_6_4_)
#         - [Champion Model](#toc2_4_3_6_5_)
#       - [Feature Engineering](#toc2_4_3_7_)
#         - [Feature Selection](#toc2_4_3_7_1_)
#         - [Feature Transformation](#toc2_4_3_7_2_)
#       - [Decision Tree - Feature Engineered](#toc2_4_3_8_)
#         - [Splitting the Data](#toc2_4_3_8_1_)
#         - [Best Parameters](#toc2_4_3_8_2_)
#         - [Best Score](#toc2_4_3_8_3_)
#         - [GridSearchCV Evaluation Metric Results](#toc2_4_3_8_4_)
#         - [Decision Tree - Featured Engineered - Prediction Performance Scores](#toc2_4_3_8_5_)
#       - [Random Forest - Feature Engineered](#toc2_4_3_9_)
#         - [Best Parameters](#toc2_4_3_9_1_)
#         - [Best Score](#toc2_4_3_9_2_)
#         - [GridSearchCV Evaluation Metric Results](#toc2_4_3_9_3_)
#         - [Random Forest - Feature Engineered - Prediction Performance Scores](#toc2_4_3_9_4_)
#       - [XGBoost - Feature Engineered](#toc2_4_3_10_)
#         - [Best Parameters](#toc2_4_3_10_1_)
#         - [Best Score](#toc2_4_3_10_2_)
#         - [GridSearchCV Evaluation Metric Results](#toc2_4_3_10_3_)
#         - [XGBoost - Feature Engineered - Predictive Performance Scores](#toc2_4_3_10_4_)
#       - [Champion Model](#toc2_4_3_11_)
#         - [Evaluation of Champion Model on Test Set](#toc2_4_3_11_1_)
#         - [Champion Model - Test Set - Prediction Performance Scores](#toc2_4_3_11_2_)
#         - [Confusion Matrix](#toc2_4_3_11_3_)
#       - [Feature Importance](#toc2_4_3_12_)
#   - [PACE: Execute Stage](#toc2_5_)
#   - [Recall evaluation metrics](#toc2_6_)
#     - [Reflect on these questions as you complete the executing stage.](#toc2_6_1_)
#   - [Step 4. Results and Evaluation](#toc2_7_)
#     - [Summary of Model Results](#toc2_7_1_)
#     - [Conclusion, Recommendations, Next Steps](#toc2_7_2_)
#   - [Appendix](#toc2_8_)
#     - [GridSearch Results](#toc2_8_1_)
#     - [GridSearch Results - Feature Engineered Only](#toc2_8_2_)
#     - [Prediction Performance Results](#toc2_8_3_)
#     - [Prediction Performance Results - Feature Engineered Only](#toc2_8_4_)
#     - [Predictions from Test Set](#toc2_8_5_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# ## <a id='toc1_1_'></a>[Scenario](#toc0_)

# %% [markdown]
# You are a data professional working for Salifort Motors.
#
# Currently, there is a high rate of turnover among Salifort employees. (Note: In this context, turnover data includes both employees who choose to quit their job and employees who are let go). Salifort’s senior leadership team is concerned about how many employees are leaving the company. Salifort strives to create a corporate culture that supports employee success and professional development. Further, the high turnover rate is costly in the financial sense. Salifort makes a big investment in recruiting, training, and upskilling its employees.
#
# If Salifort could predict whether an employee will leave the company, and discover the reasons behind their departure, they could better understand the problem and develop a solution.
#
# As a first step, the leadership team asks Human Resources to survey a sample of employees to learn more about what might be driving turnover.
#
# Next, the leadership team asks you to analyze the survey data and come up with ideas for how to increase employee retention. To help with this, they suggest you design a model that predicts whether an employee will leave the company based on their job title, department, number of projects, average monthly hours, and any other relevant data points. A good model will help the company increase retention and job satisfaction for current employees, and save money and time training new employees.
#
# As a specialist in data analysis, the leadership team leaves it up to you to choose an approach for building the most effective model to predict employee departure. For example, you could build and evaluate a statistical model such as logistic regression. Or, you could build and evaluate machine learning models such as decision tree, random forest, and XGBoost. Or, you could choose to deploy both statistical and machine learning models.
#
# For any approach, you’ll need to analyze the key factors driving employee turnover, build an effective model, and share recommendations for next steps with the leadership team.

# %% [markdown]
# ### <a id='toc1_1_1_'></a>[Data Dictionary](#toc0_)

# %% [markdown]
# This project uses a dataset called `HR_capstone_dataset.csv`. It represents 10 columns of self-reported information from employees of a multinational vehicle manufacturing corporation.
#
# The dataset contains:
#
# **14,999 rows** - Each row is a different employee's self-reported information.
#
# **10 columns**
#
# | Column name           | Type  | Description                                                            |
# |------------------------|-------|------------------------------------------------------------------------|
# | satisfaction_level     | int64 | The employee’s self-reported satisfaction level [0–1]                  |
# | last_evaluation        | int64 | Score of employee's last performance review [0–1]                      |
# | number_project         | int64 | Number of projects employee contributes to                             |
# | average_monthly_hours  | int64 | Average number of hours employee worked per month                      |
# | time_spend_company     | int64 | How long the employee has been with the company (years)                |
# | work_accident          | int64 | Whether or not the employee experienced an accident while at work      |
# | left                   | int64 | Whether or not the employee left the company                           |
# | promotion_last_5years  | int64 | Whether or not the employee was promoted in the last 5 years           |
# | department             | str   | The employee's department                                              |
# | salary                 | str   | The employee's salary (low, medium, or high)                           |

# %% [markdown]
# ## <a id='toc1_2_'></a>[Description and Deliverables](#toc0_)

# %% [markdown]
# This capstone project is an opportunity for you to analyze a dataset and build predictive models that can provide insights to the Human Resources (HR) department of a large consulting firm.
#
# Upon completion, you will have two artifacts that you would be able to present to future employers. One is a brief one-page summary of this project that you would present to external stakeholders as the data professional in Salifort Motors. The other is a complete code notebook provided here. Please consider your prior course work and select one way to achieve this given project question. Either use a regression model or machine learning model to predict whether or not an employee will leave the company.
#
# In your deliverables, you will include the model evaluation (and interpretation if applicable), a data visualization(s) of your choice that is directly related to the question you ask, ethical considerations, and the resources you used to troubleshoot and find answers or solutions.

# %% [markdown]
# # <a id='toc2_'></a>[PACE stages](#toc0_)

# %% [markdown]
# ![Screenshot 2022-08-04 5.47.37 PM.png](data:image/png;base64,...)

# %% [markdown]
# ## <a id='toc2_1_'></a>[PACE: Plan](#toc0_)
#
# Consider the questions in your PACE Strategy Document to reflect on the Plan stage.
#
# In this stage, consider the following:

# %% [markdown]
# ### <a id='toc2_1_1_'></a>[Understand the business scenario and problem](#toc0_)
#
# The HR department at Salifort Motors wants to take some initiatives to improve employee satisfaction levels at the company. They collected data from employees, but now they don’t know what to do with it. They refer to you as a data analytics professional and ask you to provide data-driven suggestions based on your understanding of the data. They have the following question: what’s likely to make the employee leave the company?
#
# Your goals in this project are to analyze the data collected by the HR department and to build a model that predicts whether or not an employee will leave the company.
#
# If you can predict employees likely to quit, it might be possible to identify factors that contribute to their leaving. Because it is time-consuming and expensive to find, interview, and hire new employees, increasing employee retention will be beneficial to the company.

# %% [markdown]
# ### <a id='toc2_1_2_'></a>[Familiarize yourself with the HR dataset](#toc0_)
#
# The dataset that you'll be using in this lab contains 15,000 rows and 10 columns for the variables listed below.
#
# **Note:** you don't need to download any data to complete this lab. For more information about the data, refer to its source on [Kaggle](https://www.kaggle.com/datasets/mfaisalqureshi/hr-analytics-and-job-prediction?select=HR_comma_sep.csv).
#
# Variable  |Description |
# -----|-----|
# satisfaction_level|Employee-reported job satisfaction level [0&ndash;1]|
# last_evaluation|Score of employee's last performance review [0&ndash;1]|
# number_project|Number of projects employee contributes to|
# average_monthly_hours|Average number of hours employee worked per month|
# time_spend_company|How long the employee has been with the company (years)
# Work_accident|Whether or not the employee experienced an accident while at work
# left|Whether or not the employee left the company
# promotion_last_5years|Whether or not the employee was promoted in the last 5 years
# Department|The employee's department
# salary|The employee's salary (U.S. dollars)

# %% [markdown]
# 💭
# ### <a id='toc2_1_3_'></a>[Reflect on these questions as you complete the plan stage.](#toc0_)
#
# *  Who are your stakeholders for this project?
# - What are you trying to solve or accomplish?
# - What are your initial observations when you explore the data?
# - What resources do you find yourself using as you complete this stage? (Make sure to include the links.)
# - Do you have any ethical considerations in this stage?

# %% [markdown]
# ### <a id='toc2_1_4_'></a>[Step 1. Imports](#toc0_)
#
# *   Import packages
# *   Load dataset

# %% [markdown]
# #### <a id='toc2_1_4_1_'></a>[Import packages](#toc0_)

# %%
# import packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import GridSearchCV, train_test_split, PredefinedSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix, ConfusionMatrixDisplay, roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from xgboost import plot_importance
import pickle

# %% [markdown]
# ### <a id='toc2_1_5_'></a>[Load dataset](#toc0_)
#
# `Pandas` is used to read a dataset called **`HR_capstone_dataset.csv`.**  As shown in this cell, the dataset has been automatically loaded in for you. You do not need to download the .csv file, or provide more code, in order to access the dataset and proceed with this lab. Please continue with this activity by completing the following instructions.

# %%
# RUN THIS CELL TO IMPORT YOUR DATA. 

# Load dataset into a dataframe

df0 = pd.read_csv("HR_capstone_dataset.csv")


# Display first few rows of the dataframe

df0.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %% [markdown]
# ### <a id='toc2_1_6_'></a>[Step 2. Data Exploration (Initial EDA and data cleaning)](#toc0_)
#
# - Understand your variables
# - Clean your dataset (missing data, redundant data, outliers)

# %% [markdown]
# #### <a id='toc2_1_6_1_'></a>[Gather basic information about the data](#toc0_)

# %%
# Gather basic information about the data

df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %% [markdown]
# #### <a id='toc2_1_6_2_'></a>[Gather descriptive statistics about the data](#toc0_)

# %%
# Gather descriptive statistics about the data

df0.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %% [markdown]
# #### <a id='toc2_1_6_3_'></a>[Rename columns](#toc0_)

# %% [markdown]
# As a data cleaning step, rename the columns as needed. Standardize the column names so that they are all in `snake_case`, correct any column names that are misspelled, and make column names more concise as needed.

# %%
# Display all column names

df0.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Department', 'salary'],
#       dtype='object')

# %%
# Rename columns as needed

df0 = df0.rename(columns={'Work_accident': 'work_accident',
                          'average_montly_hours': 'average_monthly_hours',
                          'time_spend_company': 'tenure',
                          'Department': 'department'})

# Display all column names after the update

df0.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_monthly_hours', 'tenure', 'work_accident', 'left',
#        'promotion_last_5years', 'department', 'salary'],
#       dtype='object')

# %% [markdown]
# #### <a id='toc2_1_6_4_'></a>[Check missing values](#toc0_)

# %% [markdown]
# Check for any missing values in the data.

# %%
# Check for missing values

df0.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_monthly_hours    0
# tenure                   0
# work_accident            0
# left                     0
# promotion_last_5years    0
# department               0
# salary                   0
# dtype: int64

# %% [markdown]
# #### <a id='toc2_1_6_5_'></a>[Check duplicates](#toc0_)

# %% [markdown]
# Check for any duplicate entries in the data.

# %%
# Check for duplicates

df0.duplicated().sum()
# Out:
# np.int64(3008)

# %%
# Inspect some rows containing duplicares as needed

df0[df0.duplicated()].head()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# 396                 0.46             0.57               2
# 866                 0.41             0.46               2
# 1317                0.37             0.51               2
# 1368                0.41             0.52               2
# 1461                0.42             0.53               2
#
#       average_monthly_hours  tenure  work_accident  left  \
# 396                     139       3              0     1
# 866                     128       3              0     1
# 1317                    127       3              0     1
# 1368                    132       3              0     1
# 1461                    142       3              0     1
#
#       promotion_last_5years  department  salary
# 396                       0       sales     low
# 866                       0  accounting     low
# 1317                      0       sales  medium
# 1368                      0       RandD     low
# ...

# %% [markdown]
# How plausible is it that two employees self-reported the exact same repsonse for every column? A likelihood analysis could be performed via applying Bayes' theorem and multiplying the probabilities of finding each value in each column, but this does not seem necessary. With there being several continuous variables across 10 columns it therefore seems unlikely that the observations above are legitimate and so they can be dropped.

# %%
# Drop duplicates and save resulting dataframe in a new variable as needed

df1 = df0.drop_duplicates()

# Display first few rows of new dataframe as needed

df1.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_monthly_hours  \
# 0                0.38             0.53               2                    157
# 1                0.80             0.86               5                    262
# 2                0.11             0.88               7                    272
# 3                0.72             0.87               5                    223
# 4                0.37             0.52               2                    159
#
#    tenure  work_accident  left  promotion_last_5years department  salary
# 0       3              0     1                      0      sales     low
# 1       6              0     1                      0      sales  medium
# 2       4              0     1                      0      sales  medium
# 3       5              0     1                      0      sales     low
# 4       3              0     1                      0      sales     low

# %% [markdown]
# #### <a id='toc2_1_6_6_'></a>[Check outliers](#toc0_)

# %% [markdown]
# Check for outliers in the data.

# %%
# Create a boxplot to visualize distribution of `tenure` and detect any outliers

plt.figure(figsize=(5,1))
sns.boxplot(x=df1['tenure'])
plt.title("tenure")
plt.show();

# %%
# Determine the number of rows containing outliers

percentile25 = df1['tenure'].quantile(0.25)
percentile75 = df1['tenure'].quantile(0.75)
iqr = percentile75 - percentile25

upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr

outliers = df1[(df1['tenure'] > upper_limit) | (df1['tenure'] < lower_limit)]

print("Outliers:", len(outliers))

print("Lower Limit:", lower_limit)
print("Upper Limit:", upper_limit)
# Out:
# Outliers: 824
# Lower Limit: 1.5
# Upper Limit: 5.5

# %% [markdown]
# Certain types of models are more sensitive to outliers than others. When you get to the stage of building your model, consider whether to remove outliers, based on the type of model you decide to use.

# %% [markdown]
# ## <a id='toc2_2_'></a>[PACE: Analyze Stage](#toc0_)
# - Perform EDA (analyze relationships between variables)

# %% [markdown]
# 💭
# ### <a id='toc2_2_1_'></a>[Reflect on these questions as you complete the analyze stage.](#toc0_)
#
# - What did you observe about the relationships between variables?
# - What do you observe about the distributions in the data?
# - What transformations did you make with your data? Why did you choose to make those decisions?
# - What are some purposes of EDA before constructing a predictive model?
# - What resources do you find yourself using as you complete this stage? (Make sure to include the links.)
# - Do you have any ethical considerations in this stage?

# %% [markdown]
# ### <a id='toc2_2_2_'></a>[Step 2. Data Exploration (Continue EDA)](#toc0_)
#
# Begin by understanding how many employees left and what percentage of all employees this figure represents.

# %%
# Get values of who left vs. stayed

print(df1['left'].value_counts())
print()

# Get percentages of people who left vs. stayed

print(df1['left'].value_counts(normalize=True))
# Out:
# left
# 0    10000
# 1     1991
# Name: count, dtype: int64
#
# left
# 0    0.833959
# 1    0.166041
# Name: proportion, dtype: float64

# %% [markdown]
# #### <a id='toc2_2_2_1_'></a>[Data visualizations](#toc0_)

# %% [markdown]
# Now, examine variables that you're interested in, and create plots to visualize relationships between variables in the data.

# %% [markdown]
# ##### <a id='toc2_2_2_1_1_'></a>[Satisfaction vs Turnover](#toc0_)

# %%
# Create a plot as needed

# Satisfaction vs employee turnover

sns.boxplot(x='left', y='satisfaction_level', data=df1)
plt.title("Employee Satisfaction vs Turnover")
plt.show()

# %% [markdown]
# ##### <a id='toc2_2_2_1_2_'></a>[Salary vs Turnover](#toc0_)

# %%
# Create a plot as needed

# Salary vs turnover

sns.histplot(data=df1, x='salary', hue='left', multiple='dodge')
plt.title("Employee Salary by Turnover")
plt.show()

# %% [markdown]
# ##### <a id='toc2_2_2_1_3_'></a>[Promotion vs Turnover](#toc0_)

# %%
# Create a plot as needed

# Promotion over the last 5 years vs turnover

sns.countplot(data=df1, x='promotion_last_5years', hue='left')
plt.title("Employee Promotion over 5 Years vs Turnover")
plt.show()

# %% [markdown]
# **Quick Insights:**
#
# * **Satisfaction vs Turnover:** Employess who have stayed have a higher median satisfaction, while those who left show a lower median satisfaction and wider variation. Therefore, this indicates a strong negative relationship between `satisfaction_level` and `left` as less satisfied employees are more likely to leave.
#
# * **Salary vs Turnover:** From this visualisation, it infers that employees with `low` and `median` salaries show a much higher employee turnover rate, in contrast the employees who have higher salaries rarely leave. This is an indication of compensation being a key factor in employee retention  and so by offering a competitive salary, it could significantly reduce employee turnover.
#
# * **Promotion over 5 years vs Turnover:** This visualisation infers that the employees who left Saliforts did not receive a promotion in the last 5 years. This henceforth suggests that a lack of career advancement opportunities is a major factor in employee turnover, and so by promoting internal growth and recognition this could help improve employee retention.

# %% [markdown]
# ##### <a id='toc2_2_2_1_4_'></a>[Average Monthly Hours vs Number of Projects](#toc0_)

# %% [markdown]
# The visualisation below is a stacked boxplot showing the `average_monthly_hours` distribution for the `number_project` by comparing the distributions of the employees who stayed versus those who left Salifort's.

# %%
# Create a plot as needed 

# Average Monthly Hours vs Number of Projects
sns.boxplot(data=df1, x='average_monthly_hours', y='number_project', hue='left', orient='h')
plt.title("Monthly Hours by Number of Projects")
# Out:
# Text(0.5, 1.0, 'Monthly Hours by Number of Projects')

# %% [markdown]
# ##### <a id='toc2_2_2_1_5_'></a>[Number of Projects Distribution](#toc0_)

# %%
# Create a plot as needed 

tenure_stay = df1[df1['left'] == 0]['number_project']
tenure_left = df1[df1['left'] == 1]['number_project']
sns.histplot(data=df1, x='number_project', hue='left', multiple='dodge', shrink=2)
plt.title("Number of Projects Histogram")
# Out:
# Text(0.5, 1.0, 'Number of Projects Histogram')

# %% [markdown]
# From the visulisations, we can infer that it might be natural for the employees who work longer hours to have more projects to work on, which appears evident here with the mean hours of each class increasing increasing with the number of projects being worked. However, there are two groups of employees who left the company, group A are those who worked less hours than their peers with the same number of projects and group B are those who worked much more. In group A, it is possible that they were fired or includes employees who had given in their notice and was henceforth assigned fewer working hours as they were already going to leave Salifort. In group B, we can infer that they most likely quit and that the employees in this group likely contributed tremendously to the projects they worked on, thereby making them the largest contributors to their projects.
#
# Another observation from the data visualisations is that the employees with seven projects left Salifort, with their interquartile range and those employees with six projects interquartile range being from 255-295 hours per month which is way more than any other group. This is clearly indicative of employees being overworked. It is also indicative that the optimal number of projects for the employees to work on is between 3-4, with the ratio of the employees who left vs. stayed being very small for these cohorts.
#
# Finally, if you assume a work week of 40 hours and two weeks of vaction per year, then the average number of working hours per month for employees working from Monday to Friday would be:
#
# 50 Weeks × 40 Hours per Week / 12 Months
#
# $$
# 50 × {\frac{40}{12}} = 166.67
# $$
#
# **166.67 Hours per Month**
#
# This means that, aside from the employees who worked on two projects, every other group including those who didn't leave the company, had worked considerably more hours than this. Therefore, it is evident that the employees here are being overworked.

# %% [markdown]
# Let's confirm that all the employees with seven projects left Salifort Motors.

# %%
df1[df1['number_project']==7]['left'].value_counts()
# Out:
# left
# 1    145
# Name: count, dtype: int64

# %% [markdown]
# This therefore confirms that all employees who had seven projects left Salifort Motors.

# %% [markdown]
# ##### <a id='toc2_2_2_1_6_'></a>[Average Monthly Hours vs Satisfaction](#toc0_)

# %%
# Create a plot as needed 
plt.figure(figsize=(16, 9))
sns.scatterplot(data=df1, x='average_monthly_hours', y='satisfaction_level', hue='left', alpha=0.4)
plt.axvline(x=166.67, color='#ff6361', label='166.67 hrs./mo.', ls='--')
plt.legend(labels=['left', 'stayed'])
plt.title('Average monthly hours by Satisfaction');

# %% [markdown]
# From this scatterplot, we can infer that there was a svast group of employees who worked between 240-315 hours per month who left, with 315 hours per month being over 75 hours per week for a whole year. This would explain why these group of employees satisfaction levels are close to zero. The scatterplot also infers that another group of employees who left Salifort had normal working hours with thier satisfaction still being low at around 0.4. Due to this, it is difficult to speculate as to why they left Salifort, with one possible reason being that they might of felt pressured to work more, considering the fact that many more of their peers worked more. Therefore, this pressure to work more like the other employees could explain the low satisfaction level as well as to why they left. Finally, there is a group of employees who worked between 210-280 hours per month with high satisfaction levels ranging from 0.7-0.9, who still left Salifort. These employees could have left due to a different reason such as salary or feeling like there is no career progression at Saliforts, and so while still being satisfied and working high hours, they feel like their work is unapreciated and therefore leave.
#
# Note that the strange shape of the distribution in the scatterplot is indicatibe of data manipulation or synthetic data.

# %% [markdown]
# ##### <a id='toc2_2_2_1_7_'></a>[Satisfaction vs Tenure](#toc0_)

# %%
# Create a plot as needed
plt.figure(figsize=(22, 8))
sns.boxplot(data=df1, x='satisfaction_level', y='tenure', hue='left', orient='h')
plt.title("Satisfaction by Tenure")
# Out:
# Text(0.5, 1.0, 'Satisfaction by Tenure')

# %% [markdown]
# ##### <a id='toc2_2_2_1_8_'></a>[Tenure Distribution](#toc0_)

# %%
# Create a plot as needed
tenure_stay = df1[df1['left']==0]['tenure']
tenure_left = df1[df1['left']==1]['tenure']
sns.histplot(data=df1, x='tenure', hue='left', multiple='dodge', shrink=5)
plt.title("Tenure Histogram")
# Out:
# Text(0.5, 1.0, 'Tenure Histogram')

# %% [markdown]
# From the data visualisations, we can infer that the employees who left fit into 2 categories, dissatisfied employees with shorter tenure and highly satisfied employees with medium tenures. We can also infer that the employees with four years tenure who left, have an abnormally low satisfaction level and so it is worth investigating any changes to company policy that may have affected employees specifically at the four year mark. Another observation from the visualisations are that the employees with the longest tenure who didn't leave had similar satisfaction levels with the new employees who also stayed. Finally, from the tenure histogram we can infer that there are fewer employess with long tenure which could indicate that these are higher ranking and higher paid employees at Salifort's.

# %% [markdown]
# Lets investigate the mean and median satisfaction score of the employees who left versus those who didn't.

# %%
df1.groupby(['left'])['satisfaction_level'].agg([np.mean, np.median])
# Out:
# C:\Users\alexa\AppData\Local\Temp\ipykernel_15976\3331776334.py:1: FutureWarning: The provided callable <function mean at 0x00000222964C20C0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df1.groupby(['left'])['satisfaction_level'].agg([np.mean, np.median])
# C:\Users\alexa\AppData\Local\Temp\ipykernel_15976\3331776334.py:1: FutureWarning: The provided callable <function median at 0x00000222965F65C0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   df1.groupby(['left'])['satisfaction_level'].agg([np.mean, np.median])
#           mean  median
# left
# 0     0.667365    0.69
# 1     0.440271    0.41

# %% [markdown]
# The mean and median satisfaction scores of the employees who left are lower than those of the employees who stayed. Amoung the employees who stayed the mean satisfaction score is slightly lower than the median score, which indicates that the satisfaction levels for the employees who stayed might be skewed to the left.

# %% [markdown]
# ##### <a id='toc2_2_2_1_9_'></a>[Salary vs Tenure](#toc0_)

# %%
# Create a plot as needed 
fig, ax = plt.subplots(1, 2, figsize = (22,8))

tenure_short = df1[df1['tenure'] < 7]
tenure_long = df1[df1['tenure'] > 6]

sns.histplot(data=tenure_short, x='tenure', hue='salary', hue_order=['low', 'medium', 'high'], multiple='dodge', shrink=5, ax=ax[0])
ax[0].set_title("Salary Histogram by Tenure: Short-tenured Employees", fontsize='14')

sns.histplot(data=tenure_long, x='tenure', hue='salary', hue_order=['low', 'medium', 'high'], multiple='dodge', ax=ax[1])
ax[1].set_title("Salary Histogram by Tenure: Long-tenured Employees", fontsize='14')
# Out:
# Text(0.5, 1.0, 'Salary Histogram by Tenure: Long-tenured Employees')

# %% [markdown]
# The histograms show that the employees with long tenure were not disproportionately comprised of higher paid employees, with in fact a majority being medium paid.

# %% [markdown]
# ##### <a id='toc2_2_2_1_10_'></a>[Average Monthly Hours vs Last Evaluation](#toc0_)

# %% [markdown]
# Let's investigate whether there is a correlation between an employee working long hours and an employee receiving high evaluation scores.

# %%
# Create a plot as needed 
plt.figure(figsize=(16, 9))
sns.scatterplot(data=df1, x='average_monthly_hours', y='last_evaluation', hue='left', alpha=0.4)
plt.axvline(x=166.67, color='#ff6361', label='166.67 hrs./mo.', ls='--')
plt.legend(labels=['left', 'stayed'])
plt.title("Monthyl Hours by Last Evaluation Score")
# Out:
# Text(0.5, 1.0, 'Monthyl Hours by Last Evaluation Score')

# %% [markdown]
# From the scatterplot we can observe that there are two types of employees who left, those who were overworked and performed extremely well on evaluation scores and those who worked under the monthly average of 166 hours per month with lower evaluation scores. This connects with the possible reason for turnover being lack of recognition or burnout. Another observation is that the scatterplot shows that there is a correlaton between hours worked and evaluation score. Also, there isn't a high percentage of employees in the upper left of the plot, which is working short hours and achieving a high evaluation score, but also keep in mind that working long hours doesn't guarantee a good evaluation score. Finally, it is evident from the plot that a majority of the employees at Salifort Motors work over 167 hours per month.

# %% [markdown]
# ##### <a id='toc2_2_2_1_11_'></a>[Average Monthly Hours vs Promotion](#toc0_)

# %%
# Create a plot as needed 
plt.figure(figsize=(16, 3))
sns.scatterplot(data=df1, x='average_monthly_hours', y='promotion_last_5years', hue='left', alpha=0.4)
plt.axvline(x=166.67, color='#ff6361', ls='--')
plt.legend(labels=['left', 'stayed'])
plt.title('Monthly hours by promotion last 5 years', fontsize='14');

# %% [markdown]
# We can infer from this scatterplot that out of the employees who received a promotion in the last five years, very few left. This shows that due to getting work recognition and shown clear career progression via promotions, the employees stayed at Salifort. The plot also shows that very few employees who worked long hours were given a promotion, which shows that either employees hard work is not being recognised as well as that working long hours doesn't guarantee a promotion or career progression. Finally, majority of the employees who left were working the longest hours.

# %% [markdown]
# Let's investigate how the employees who left are distributed across the Salifort's departments.

# %%
df1[df1['left']==1]['department'].value_counts()
# Out:
# department
# sales          550
# technical      390
# support        312
# IT             158
# hr             113
# marketing      112
# product_mng    110
# accounting     109
# RandD           85
# management      52
# Name: count, dtype: int64

# %% [markdown]
# ##### <a id='toc2_2_2_1_12_'></a>[Department vs Turnover](#toc0_)

# %%
# Create a plot as needed 
plt.figure(figsize=(11,8))
sns.histplot(data=df1, x='department', hue='left', discrete=1, hue_order=[0, 1], multiple='dodge', shrink=.5)
plt.xticks(rotation=45, ha='right')
plt.title("Department by Employee Turnover")
# Out:
# Text(0.5, 1.0, 'Department by Employee Turnover')

# %% [markdown]
# From this data visualisation it is evident that there doesn't seem to be any department that differs significantly in its proportion of employees who left versus those who stayed, although, it is slightly higher in the sales, technical and support departments. This therefore suggests that while department alone isn't the main driver of employee turnover, more frontline and technical roles may face more stress and workload's and thereby contributes to a higher turnover rate.

# %% [markdown]
# ##### <a id='toc2_2_2_1_13_'></a>[Heatmap](#toc0_)

# %%
# Create a plot as needed 
plt.figure(figsize=(16, 9))
num = df0.select_dtypes(include=np.number)
corr = num.corr()
heatmap = sns.heatmap(corr, vmin=-1, vmax=1, annot=True, cmap=sns.color_palette("vlag", as_cmap=True))
heatmap.set_title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# The correlation heatmap shows that the number of projects, average monthly hours and evaluation scores all have some positive correlation with each other, while whether an employee leaves is strongly negatively correlated with satisfaction level at -0.39. This shows that satisfaction is a major factor in employee turnover. It is also evident from the heatmap that there is a mild positive correlation between tenure and left at 0.14, thereby indicating that mid tenure employees are more likely to leave. The other features have relatively weak correlations and so therefore implies that satisfaction level is the primary driver of employee turnvoer.

# %% [markdown]
# **Insights**
#
# It therefore appears that employees are leaving Salifort Motors due to poor management, with leaving the company being connected to longer working hours, many projects and generally low satisfaction levels. It can be dissatisfying to work continously long hours all to not recieve recognition in the form of promotions or good evaluation scores, with there being a sizeable group of employees who are most likely burned out. It is also evident that if an employee spends more than six years at the company then they tend not to leave.

# %% [markdown]
# ## <a id='toc2_3_'></a>[PACE: Construct](#toc0_)

# %% [markdown]
# - Determine which models are most appropriate
# - Construct the model
# - Confirm model assumptions
# - Evaluate model results to determine how well your model fits the data

# %% [markdown]
# 🔎
# ## <a id='toc2_4_'></a>[Recall model assumptions](#toc0_)
#
# **Logistic Regression model assumptions**
# - Outcome variable is categorical
# - Observations are independent of each other
# - No severe multicollinearity among X variables
# - No extreme outliers
# - Linear relationship between each X variable and the logit of the outcome variable
# - Sufficiently large sample size

# %% [markdown]
# 💭
# ### <a id='toc2_4_1_'></a>[Reflect on these questions as you complete the constructing stage.](#toc0_)
#
# - Do you notice anything odd?
# - Which independent variables did you choose for the model and why?
# - Are each of the assumptions met?
# - How well does your model fit the data?
# - Can you improve it? Is there anything you would change about the model?
# - What resources do you find yourself using as you complete this stage? (Make sure to include the links.)
# - Do you have any ethical considerations in this stage?

# %% [markdown]
# ### <a id='toc2_4_2_'></a>[Step 3. Model Building, Step 4. Results and Evaluation](#toc0_)
# - Fit a model that predicts the outcome variable using two or more independent variables
# - Check model assumptions
# - Evaluate the model

# %% [markdown]
# #### <a id='toc2_4_2_1_'></a>[Identify the type of prediction task.](#toc0_)

# %% [markdown]
# The goal is to predict whether an employee leaves Salifort Motors, which is a categorical outcome variable. Therefore, this task involves classification, more specifically binary classification due to the target variable `left` can be either equal to 1 (the employee left) or 0 (the employee stayed).

# %% [markdown]
# #### <a id='toc2_4_2_2_'></a>[Identify the types of models most appropriate for this task.](#toc0_)

# %% [markdown]
# * Logistic Regression
# * Naive Bayes
# * Decision Trees
# * Random Forest
# * XGBoost

# %% [markdown]
# ### <a id='toc2_4_3_'></a>[Modeling](#toc0_)
#
# Add as many cells as you need to conduct the modeling process.

# %% [markdown]
# #### <a id='toc2_4_3_1_'></a>[Data Preparation](#toc0_)

# %%
df_enc = df1.copy()

df_enc['salary'] = (df_enc['salary'].astype('category').cat.set_categories(['low', 'medium', 'high']).cat.codes)

df_enc = pd.get_dummies(df_enc, drop_first=False)

df_enc.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_monthly_hours  \
# 0                0.38             0.53               2                    157
# 1                0.80             0.86               5                    262
# 2                0.11             0.88               7                    272
# 3                0.72             0.87               5                    223
# 4                0.37             0.52               2                    159
#
#    tenure  work_accident  left  promotion_last_5years  salary  department_IT  \
# 0       3              0     1                      0       0          False
# 1       6              0     1                      0       1          False
# 2       4              0     1                      0       1          False
# 3       5              0     1                      0       0          False
# 4       3              0     1                      0       0          False
#
# ...

# %% [markdown]
# Let's visualise how correlated the variables are with each other via a Heatmap.

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df_enc[['satisfaction_level', 'last_evaluation', 'number_project', 'average_monthly_hours', 'tenure']]
            .corr(), annot=True, cmap="crest")
plt.title('Heatmap of the dataset')
plt.show()

# %% [markdown]
# Now let's create a stacked bar plot to visualize number of employees across department, comparing those who left with those who didn't.

# %%
pd.crosstab(df1['department'], df1['left']).plot(kind ='bar',color='mr')
plt.title('Counts of Employee Turnover vs. Department')
plt.ylabel('Employee count')
plt.xlabel('Department')
plt.show()

# %% [markdown]
# Due to Logistic Regression being sensitive to outliers, we will remove the outliers for the data for the Logistic Regression Model. These are in the `tenure` column, that we identified previously.

# %%
df_log = df_enc[(df_enc['tenure'] >= lower_limit) & (df_enc['tenure'] <= upper_limit)]

df_log.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_monthly_hours  \
# 0                0.38             0.53               2                    157
# 2                0.11             0.88               7                    272
# 3                0.72             0.87               5                    223
# 4                0.37             0.52               2                    159
# 5                0.41             0.50               2                    153
#
#    tenure  work_accident  left  promotion_last_5years  salary  department_IT  \
# 0       3              0     1                      0       0          False
# 2       4              0     1                      0       1          False
# 3       5              0     1                      0       0          False
# 4       3              0     1                      0       0          False
# 5       3              0     1                      0       0          False
#
# ...

# %% [markdown]
# #### <a id='toc2_4_3_2_'></a>[Logistic Regression](#toc0_)

# %% [markdown]
# ##### <a id='toc2_4_3_2_1_'></a>[Splitting the Data](#toc0_)

# %% [markdown]
# Checking the class balance of the target variable

# %%
df_log['left'].value_counts(normalize=True)
# Out:
# left
# 0    0.831468
# 1    0.168532
# Name: proportion, dtype: float64

# %% [markdown]
# There is an approximately 83%-17% split and so the data is not perfectly balanced but it is not too imbalanced.

# %% [markdown]
# We will make a Training, Validation and Testing set, which is split up 60/20/20 and will be stratifying using `y` as there is a small class imbalance.

# %%
y = df_log['left']

X = df_log.drop('left', axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
X_tr, X_val, y_tr, y_val = train_test_split(X_train, y_train, test_size=0.25, stratify=y_train, random_state=42)

# %%
print(X_tr.shape)
print(y_tr.shape)
print(X_val.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (6699, 18)
# (6699,)
# (2234, 18)
# (2234,)
# (2234, 18)
# (2234,)

# %% [markdown]
# Instantiate the Model

# %%
clf = LogisticRegression(random_state=42, max_iter=500)
clf.fit(X_tr, y_tr)
# Out:
# LogisticRegression(max_iter=500, random_state=42)

# %% [markdown]
# Coefficients

# %%
clf.coef_
# Out:
# array([[-4.33317050e+00, -1.10551893e-01, -4.92448752e-01,
#          3.97645036e-03,  1.10117521e+00, -1.56389388e+00,
#         -1.44531769e+00, -5.13488753e-01, -1.27339433e-01,
#         -4.22671575e-01, -1.25372748e-01, -5.98794820e-04,
#         -2.16756091e-01,  2.00548164e-02, -8.16881339e-02,
#          5.85192113e-02,  5.99004985e-02,  2.42580129e-02]])

# %% [markdown]
# These are the coefficients for $\beta$ 1-18

# %% [markdown]
# Intercept

# %%
clf.intercept_
# Out:
# array([-1.31697947])

# %% [markdown]
# The estimated intercept for $\beta_0$ is -1.317

# %% [markdown]
# ##### <a id='toc2_4_3_2_2_'></a>[Predictions on the Validation Set](#toc0_)

# %%
y_log_pred = clf.predict(X_val)

# %% [markdown]
# ##### <a id='toc2_4_3_2_3_'></a>[Confusion Matrix - Validation Set](#toc0_)

# %%
cm = confusion_matrix(y_val, y_log_pred, labels=clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=clf.classes_)
disp.plot()
plt.title("Logistic Regression - Validation Set")
plt.show()

# %% [markdown]
# ##### <a id='toc2_4_3_2_4_'></a>[Classification Report](#toc0_)

# %%
target_labels = ['Predicted would not leave', 'Predicted would leave']
print(classification_report(y_val, y_log_pred, target_names=target_labels))
# Out:
#                            precision    recall  f1-score   support
#
# Predicted would not leave       0.86      0.94      0.90      1858
#     Predicted would leave       0.46      0.24      0.32       376
#
#                  accuracy                           0.83      2234
#                 macro avg       0.66      0.59      0.61      2234
#              weighted avg       0.79      0.83      0.80      2234

# %% [markdown]
# **Confusion Matrix**
#
# * **True Negatives = 1752** Most employees who stayed were correctly predicted as staying.
# * **False Positives = 106** A small number of stayers were incorrectly flagged as likely to leave.
# * **False Negatives = 284** A large number of employees who actually left were predicted to stay.
# * **True Positives = 92** Only a relatively small portion of true leavers were correctly identified.
#
# These patterns indicate that the Logistic Regression Model is much better at recognising employees who stay then detecting employees risk of leaving.
#
# **Classification Report**
#
# * **Predicted would not leave (0)** - Precision = 0.86, Recall = 0.94, F1-Score = 0.90 - The Model was good at predicting whether an employee will stay.
# * **Predicted would leave (1)** - Precision = 0.46, Recall = 0.24, F1-Score = 0.32 - The Model struggled to predict whether an employee would leave
# * **Overall Accuracy** - 0.83 The Model correctly classifies 83% of cases.
#
# The Logistic Regression Model achieves an overall accuracy of 83% on the Validation set and is strong at identifying employees who stay, with it correctly classifying majority of non-leavers with a Precision of 0.86 and a Recall of 0.94. However, it performs poorly for the employees who actually leave with only 92 out of 376 leavers being correctly identified, with a Precision of 0.46 and a Recall of 0.24. In terms of Salifort's use case, where failing to detect a true leaver is costly, this imbalance shows that although the Model is a reasonable baseline, it is not sufficiently effective at capturing high-risk employees and therefore should be compared against more powerful Models.

# %% [markdown]
# #### <a id='toc2_4_3_3_'></a>[Helper Functions](#toc0_)

# %% [markdown]
# ##### <a id='toc2_4_3_3_1_'></a>[make_results()](#toc0_)

# %%
def make_results(model_name:str, model_object, metric:str):
    '''
    Arguments:
        model_name (string): what you want the model to be called in the output table
        model_object: a fit GridSearchCV object
        metric (string): precision, recall, f1, accuracy, or auc
  
    Returns a pandas df with the F1, recall, precision, accuracy, and auc scores
    for the model with the best mean 'metric' score across all validation folds.  
    '''

    # Create dictionary that maps input metric to actual metric name in GridSearchCV
    metric_dict = {'auc': 'mean_test_roc_auc',
                   'precision': 'mean_test_precision',
                   'recall': 'mean_test_recall',
                   'f1': 'mean_test_f1',
                   'accuracy': 'mean_test_accuracy'
                  }

    # Get all the results from the CV and put them in a df
    cv_results = pd.DataFrame(model_object.cv_results_)

    # Isolate the row of the df with the max(metric) score
    best_estimator_results = cv_results.iloc[cv_results[metric_dict[metric]].idxmax(), :]

    # Extract Accuracy, precision, recall, and f1 score from that row
    auc = best_estimator_results.mean_test_roc_auc
    f1 = best_estimator_results.mean_test_f1
    recall = best_estimator_results.mean_test_recall
    precision = best_estimator_results.mean_test_precision
    accuracy = best_estimator_results.mean_test_accuracy
  
    # Create table of results
    table = pd.DataFrame()
    table = pd.DataFrame({'model': [model_name],
                          'precision': [precision],
                          'recall': [recall],
                          'F1': [f1],
                          'accuracy': [accuracy],
                          'auc': [auc]
                        })
  
    return table

# %% [markdown]
# ##### <a id='toc2_4_3_3_2_'></a>[get_results()](#toc0_)

# %%
def get_scores(model_name:str, model, X_test_data, y_test_data):
    '''
    Generate a table of test scores.

    In: 
        model_name (string):  How you want your model to be named in the output table
        model:                A fit GridSearchCV object
        X_test_data:          numpy array of X_test data
        y_test_data:          numpy array of y_test data

    Out: pandas df of precision, recall, f1, accuracy, and AUC scores for your model
    '''

    preds = model.best_estimator_.predict(X_test_data)

    auc = roc_auc_score(y_test_data, preds)
    accuracy = accuracy_score(y_test_data, preds)
    precision = precision_score(y_test_data, preds)
    recall = recall_score(y_test_data, preds)
    f1 = f1_score(y_test_data, preds)

    table = pd.DataFrame({'model': [model_name],
                          'precision': [precision], 
                          'recall': [recall],
                          'f1': [f1],
                          'accuracy': [accuracy],
                          'AUC': [auc]
                         })
  
    return table

# %% [markdown]
# ##### <a id='toc2_4_3_3_3_'></a>[write_pickle()](#toc0_)

# %%
def write_pickle(path, model_object, save_as:str):
    '''
    In: 
        path:         path of folder where you want to save the pickle
        model_object: a model you want to pickle
        save_as:      filename for how you want to save the model

    Out: A call to pickle the model in the folder indicated
    '''    

    with open(path + save_as + '.pickle', 'wb') as to_write:
        pickle.dump(model_object, to_write)

# %% [markdown]
# ##### <a id='toc2_4_3_3_4_'></a>[read_pickle()](#toc0_)

# %%
def read_pickle(path, saved_model_name:str):
    '''
    In: 
        path:             path to folder where you want to read from
        saved_model_name: filename of pickled model you want to read in

    Out: 
        model: the pickled model 
    '''
    with open(path + saved_model_name + '.pickle', 'rb') as to_read:
        model = pickle.load(to_read)

    return model

# %% [markdown]
# #### <a id='toc2_4_3_4_'></a>[Decision Tree](#toc0_)

# %% [markdown]
# ##### <a id='toc2_4_3_4_1_'></a>[Splitting the Data](#toc0_)

# %%
y = df_enc['left']

X = df_enc.drop('left', axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
X_tr, X_val, y_tr, y_val = train_test_split(X_train, y_train, test_size=0.25, stratify=y_train, random_state=42)

# %%
print(X_tr.shape)
print(y_tr.shape)
print(X_val.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (7194, 17)
# (7194,)
# (2398, 17)
# (2398,)
# (2399, 17)
# (2399,)

# %% [markdown]
# Now we will construct a Decision Tree Classifier and Hyperparameter Tune it with GridSearch as well as to Cross-Validate it in order to find the best Model Parameters.

# %%
tree = DecisionTreeClassifier(random_state=42)

cv_params = {'max_depth': [2, 4, 5, 6, 8, 10, 15, 20, 30, 40, 50],
             'min_samples_leaf': [2, 5, 10, 20, 50],
             'min_samples_split': [2, 3, 4, 5, 6]}

scoring = ['accuracy', 'precision', 'recall', 'f1', 'roc_auc']

tree_cv = GridSearchCV(tree, cv_params, scoring=scoring, cv=5, refit='recall')

# %%
# %%time
tree_cv.fit(X_tr, y_tr)
# Out:
# CPU times: total: 32.8 s
# Wall time: 33.9 s
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42),
#              param_grid={'max_depth': [2, 4, 5, 6, 8, 10, 15, 20, 30, 40, 50],
#                          'min_samples_leaf': [2, 5, 10, 20, 50],
#                          'min_samples_split': [2, 3, 4, 5, 6]},
#              refit='recall',
#              scoring=['accuracy', 'precision', 'recall', 'f1', 'roc_auc'])

# %% [markdown]
# Best Parameters

# %%
tree_cv.best_params_
# Out:
# {'max_depth': 4, 'min_samples_leaf': 2, 'min_samples_split': 2}

# %% [markdown]
# Best Score

# %% [markdown]
# This is the best Recall Score achieved by the Decision Tree Model on the Training Set

# %%
tree_cv.best_score_
# Out:
# np.float64(0.9138075313807532)

# %% [markdown]
# The best Recall Score is 0.91, which shows that the Model is great at predicting the employees who leave very well.

# %% [markdown]
# ##### <a id='toc2_4_3_4_2_'></a>[GridSearchCV Evaluation Metric Results](#toc0_)

# %% [markdown]
# Let's use the helper function `make_results()` to get all the scores from the GridSearch

# %%
tree_cv_results = make_results('Decision Tree CV', tree_cv, 'recall')
tree_cv_results
# Out:
#               model  precision    recall        F1  accuracy       auc
# 0  Decision Tree CV   0.913655  0.913808  0.913306  0.971226  0.969794

# %% [markdown]
# **Insights**

# %% [markdown]
# The Tuned Decision Tree Classifier performs strongly and it achieves a Recall of 0.91 which means it correctly identifies the large majority of employees who leave, while maintaining a high Precision of 0.91 and an F1-Score of 0.91. The overall Accuracy is 0.97 with a ROC AUC Score of 0.97, thereby indicating excellent seperation between employees who stayed and those who left, making it a competitive candidate for the employee turnover task.

# %% [markdown]
# ##### <a id='toc2_4_3_4_3_'></a>[Decision Tree - Prediction Performance Scores](#toc0_)

# %% [markdown]
# We can use the `get_scores()` function in order to get all the scores from the Tuned Decision Tree Classifiers Predictions.

# %%
tree_cv_val_scores = get_scores('Decision Tree CV Val', tree_cv, X_val, y_val)
tree_cv_val_scores
# Out:
#                   model  precision    recall        f1  accuracy       AUC
# 0  Decision Tree CV Val      0.925  0.929648  0.927318  0.975813  0.957324

# %% [markdown]
# **Insights**

# %% [markdown]
# The Tuned Decision Tree Classifier predicted exceptionally well on the validation set with a Precision of 0.93, Recall of 0.93, F1-Score of 0.93 with an overall accuracy of 0.98 and a ROC AUC of 0.96. This means that the Model can reliably distinguish between employees who leave from those who stay all while keeping False Positives and False Negatives very low.

# %% [markdown]
# But bare in mind that Decision Trees can be vulnerable to overfitting the data, and so Random Forests avoid overfitting by incorporating multiple Decision Trees in order to make predictions.

# %% [markdown]
# #### <a id='toc2_4_3_5_'></a>[Random Forest](#toc0_)

# %% [markdown]
# Next we will construct a Random Forest Model and Hyperparameter Tune and Cross-Validate it in order to find the best Model Parameters.

# %%
rf = RandomForestClassifier(random_state=42)

cv_params = {'max_depth': [2, 3, 5, None],
             'min_samples_leaf': [1, 2, 5, 10],
             'min_samples_split': [2, 4, 5, 6],
             'max_features': [2, 4, 5],
             'n_estimators': [50, 75, 100, 200, 300, 500]}

scoring = ['accuracy', 'precision', 'recall', 'f1', 'roc_auc']

rf_cv = GridSearchCV(rf, cv_params, scoring=scoring, cv=5, refit='recall')

# %%
# %%time
rf_cv.fit(X_tr, y_tr)

# %% [markdown]
# Due to the long run time of the Random Forest Model, lets save it as a pickle file, so that way we can quickly import it later.

# %%
path = 'E:/Coursera/Google Advanced Data Analytics/Capstone Project/Portfolio/'

# %%
write_pickle(path, rf_cv, 'rf_cv')

# %%
rf_cv = read_pickle(path, 'rf_cv')

# %% [markdown]
# ##### <a id='toc2_4_3_5_1_'></a>[Best Parameters](#toc0_)

# %%
rf_cv.best_params_
# Out:
# {'max_depth': None,
#  'max_features': 5,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 50}

# %% [markdown]
# ##### <a id='toc2_4_3_5_2_'></a>[Best Score](#toc0_)

# %%
rf_cv.best_score_
# Out:
# np.float64(0.9087866108786612)

# %% [markdown]
# The best Recall Score achieved by the best Model is 0.91, thereby showing that the Model is great at predicting leavers.

# %% [markdown]
# ##### <a id='toc2_4_3_5_3_'></a>[GridSearchCV Evaluation Metric Results](#toc0_)

# %% [markdown]
# Now we will collect the evaluation metric scores on the training data for the Random Forest Model

# %%
rf_cv_results = make_results('Random Forest CV', rf_cv, 'recall')
rf_cv_results
# Out:
#               model  precision    recall        F1  accuracy       auc
# 0  Random Forest CV   0.986504  0.908787  0.945811  0.982763  0.974068

# %%
results = pd.concat([tree_cv_results, rf_cv_results])
results
# Out:
#               model  precision    recall        F1  accuracy       auc
# 0  Decision Tree CV   0.913655  0.913808  0.913306  0.971226  0.969794
# 0  Random Forest CV   0.986504  0.908787  0.945811  0.982763  0.974068

# %% [markdown]
# **Insights**

# %% [markdown]
# The evaluation metrics from the GridSearchCV shows that both of the Tuned Models performed strongly, but the Random Forest Classifier consistently outperforms the Decision Tree as it achieves a higher Precision of 0.99, F1-Score of 0.95, a ROC AUC of 0.97, and a overall accuracy of 0.98 with a comparable Recall of 0.91. Therefore, this makes the Random Forest Model the stronger candidate for predicting employee turnover.

# %% [markdown]
# ##### <a id='toc2_4_3_5_4_'></a>[Random Forest - Prediction Performance Scores](#toc0_)

# %% [markdown]
# Now we can use the `get_scores()` function to get the evaluation metrics from the Random Forest Model's predictions

# %%
rf_cv_val_scores = get_scores('Random Forest CV Val', rf_cv, X_val, y_val)
val_scores = pd.concat([tree_cv_val_scores, rf_cv_val_scores])
val_scores
# Out:
#                   model  precision    recall        f1  accuracy       AUC
# 0  Decision Tree CV Val   0.925000  0.929648  0.927318  0.975813  0.957324
# 0  Random Forest CV Val   0.989276  0.927136  0.957198  0.986239  0.962568

# %% [markdown]
# **Insights**

# %% [markdown]
# On the validation set, both of the Tuned Models performed well, but the Random Forest Classifier is clearly in the lead as it has a higher Precision of 0.99 vs the Decision Tree's 0.93, a higher F1-Score of 0.96 vs 0.93, higher overall Accuracy of 0.99 vs 0.98 and a slightly better ROC AUC all while maintaining Recall comparable to the Decision Tree. This thereby confirms that the Random Forest Model is the stronger and more reliable choice.

# %% [markdown]
# #### <a id='toc2_4_3_6_'></a>[XGBoost](#toc0_)

# %% [markdown]
# Let's compare the Decision Tree and the Random Forest to one more approach, XGBoost.

# %% [markdown]
# Now we will instantiate a XGBoost Model and Hyperparameter Tune and Cross-Validate it via GridSearch in order to find the best Model Parameters.

# %%
xgb = XGBClassifier(objective='binary:logistic', random_state=42)

cv_params = {'max_depth': [4, 5, 10, None],
             'min_child_weight': [4, 8, 10],
             'learning_rate': [0.1, 0.2, 0.3],
             'n_estimators': [75, 100, 125],
             'colsample_bytree': [0.25, 0.5, 0.75]}

scoring = ['accuracy', 'precision', 'recall', 'f1', 'roc_auc']

xgb_cv = GridSearchCV(xgb, cv_params, scoring=scoring, cv=5, refit='recall')

# %%
# %%time
xgb_cv.fit(X_tr, y_tr)

# %% [markdown]
# Let's save it as a pickle

# %%
write_pickle(path, xgb_cv, 'xgb_cv')

# %%
xgb_cv = read_pickle(path, 'xgb_cv')

# %% [markdown]
# ##### <a id='toc2_4_3_6_1_'></a>[Best Parameters](#toc0_)

# %%
xgb_cv.best_params_
# Out:
# {'colsample_bytree': 0.75,
#  'learning_rate': 0.2,
#  'max_depth': 4,
#  'min_child_weight': 4,
#  'n_estimators': 100}

# %% [markdown]
# ##### <a id='toc2_4_3_6_2_'></a>[Best Score](#toc0_)

# %%
xgb_cv.best_score_
# Out:
# np.float64(0.9112970711297071)

# %% [markdown]
# The best Recall Score by the best Model according to the GridSearch is 0.91, which shows that the Model is excellent at identifying employees who leave.

# %% [markdown]
# ##### <a id='toc2_4_3_6_3_'></a>[GridSearchCV Evaluation Metric Results](#toc0_)

# %% [markdown]
# Now let's collect the results of the evaluation metrics on the training data by the XGBoost Classifier.

# %%
xgb_cv_results = make_results('XGB CV', xgb_cv, 'recall')
results = pd.concat([results, xgb_cv_results])
results
# Out:
#               model  precision    recall        F1  accuracy       auc
# 0  Decision Tree CV   0.913655  0.913808  0.913306  0.971226  0.969794
# 0  Random Forest CV   0.986504  0.908787  0.945811  0.982763  0.974068
# 0            XGB CV   0.965909  0.911297  0.937448  0.979844  0.983030

# %% [markdown]
# **Insights**

# %% [markdown]
# On the training data all three Tuned Models performed strongly. The Random Forest Model achieved the highest overall F1-Score of 0.95 and Accuracy of 0.98, while the XGBoost delivered similarly high performance with the best ROC AUC of 0.98 thereby indicating excellent class seperation. The Decision Tree lags slightly behind both of the ensembles but is still strong.

# %% [markdown]
# ##### <a id='toc2_4_3_6_4_'></a>[XGBoost - Prediction Performance Scores](#toc0_)

# %% [markdown]
# Here we will use the `get_scores()` function to view the evaluation metrics from the XGBoost Model's predictions on the Validation Set.

# %%
xgb_cv_val_scores = get_scores('XGB CV Val', xgb_cv, X_val, y_val)
val_scores = pd.concat([val_scores, xgb_cv_val_scores])
val_scores
# Out:
#                   model  precision    recall        f1  accuracy       AUC
# 0  Decision Tree CV Val   0.925000  0.929648  0.927318  0.975813  0.957324
# 0  Random Forest CV Val   0.989276  0.927136  0.957198  0.986239  0.962568
# 0            XGB CV Val   0.968170  0.917085  0.941935  0.981234  0.955543

# %% [markdown]
# **Insights**

# %% [markdown]
# On the validation set, all three of the Tuned Models performed strongly but with clear differences between them. The Decision Tree Classifier achieved a solid Recall of 0.93 and Accuracy of 0.98 but lagged behind the ensembles. Whereas the XGBoost Model improves overall performance with its Precision at 0.97, F1-Score at 0.94 and Accuracy at 0.98 but it still trails behind the Random Forest Model. The Random Forest Model delivers the best balance with the highest Precision at 0.99, strongest F1-Score at 0.96, top accuracy at 0.99 and leading ROC AUC at 0.96, making it the strongest candidate amoung the three.

# %% [markdown]
# ##### <a id='toc2_4_3_6_5_'></a>[Champion Model](#toc0_)

# %% [markdown]
# The Random Forest Classifier is selected as the Champion Model due to the fact it consistently delivers the strongest and most balanced performance across the evaluation metrics all while remaining relatively interpretable. On the Validation set, it achieved the highest Precision (0.99), F1-Score (0.96), Accuracy (0.99) and leading ROC AUC, indicating it can reliably identify employees at risk of leaving with few false alarms. In comparison with the XGBoost Model, the Random Forest's predictions are easier to explain as they come from ensembles of transparent Decision Trees with accessible feature importances, which is crucial for HR, legal and leadership stakeholders who must trust and act on the Model. In contrast, Gradient Boosting Machines (GBMs) like XGBoost act more like black boxes that can overfit when many Hyperparameters are aggressively tuned and also tend to struggle with Extrapolation outside the training data pattern. Given that Salifort Motor's need for both high predictive power, interpretablity and stable behaviour, the Random Forest Model is the most appropriate choice.

# %% [markdown]
# #### <a id='toc2_4_3_7_'></a>[Feature Engineering](#toc0_)

# %% [markdown]
# There is a chance that there is some data leakage occuring due to skepticism of the high evaluation metric scores. Data leakage is when data that should not be used during the training of the Model is used, either due to it appearing in the test data or due to it not being the data that you would expect to have when the Model is actually deployed. The consequence of training a Model with leaked data is that it can give an unrealistic score that is not replicated in production.
#
# In this instance, it is likely that Salifort Motor's won't have satisfaction levels reported for all of its employees and it is also likely that the column `average_monthly_hours` is a source of some of the data leakage. This is because if employees have already decided on quiting or have already been identified by management as people to be fired, then they may be working fewer hours.
#
# The Models built included all the variables as features, the next set of Models will incorporate feature engineering in order to build improved Models.

# %% [markdown]
# ##### <a id='toc2_4_3_7_1_'></a>[Feature Selection](#toc0_)

# %% [markdown]
# Let's start by dropping the `satisfaction_level` variable from the data.

# %%
df2 = df_enc.drop('satisfaction_level', axis=1)
df2.head()
# Out:
#    last_evaluation  number_project  average_monthly_hours  tenure  \
# 0             0.53               2                    157       3
# 1             0.86               5                    262       6
# 2             0.88               7                    272       4
# 3             0.87               5                    223       5
# 4             0.52               2                    159       3
#
#    work_accident  left  promotion_last_5years  salary  department_IT  \
# 0              0     1                      0       0          False
# 1              0     1                      0       1          False
# 2              0     1                      0       1          False
# 3              0     1                      0       0          False
# 4              0     1                      0       0          False
#
#    department_RandD  department_accounting  department_hr  \
# 0             False                  False          False
# ...

# %% [markdown]
# ##### <a id='toc2_4_3_7_2_'></a>[Feature Transformation](#toc0_)

# %% [markdown]
# Next we can create a new Variable called `overworked` that roughly captures whether an employee is overworked and will be a Binary Variable.

# %%
df2['overworked'] = df2['average_monthly_hours']

# %%
print("Max Hours:", df2['overworked'].max())
print("Min Hours:", df2['overworked'].min())
# Out:
# Max Hours: 310
# Min Hours: 96

# %% [markdown]
# 166.67 hours per month is the approximate number of monthly hours for someone who works 50 weeks per year, 5 days per week and 8 hours per day. However, using 166.67/167 hours per month is basically "normal" full time work, and so using that as a threshold for an employee being overworked, would label lots of typical workloads as overworked and muddy the signal. Therefore, a threshold of 175 hours per month can better capture the sustained overtime and provides a clearer and more meaningful split between regular and genuinely high workloads. Hence, we define an employee being overworked as working more than 175 hours per month on average.

# %%
df2['overworked'] = (df2['overworked'] > 175).astype(int)
df2['overworked'].head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: overworked, dtype: int64

# %% [markdown]
# Now we will drop the `average_monthly_hours` column from the data.

# %%
df2 = df2.drop('average_monthly_hours', axis=1)

# %% [markdown]
# **Note:** We won't be performing the Logistic Regression in the next round with the Feature Engineered data. This is because on the validation set it showed a low Recall of 0.24 and F1-Score for the employees who left, thereby meaning that it missed majority of the employees who actually left and is clearly worse than the tree-based Models. This is unacceptable for our use case as it is costly to Salifort Motor's to miss a leaver. The Logistic Regression was tested and it underperformed and so we will focus this second-round optimisations on the Decision Tree, Random Forest and XGBoost Classifiers.

# %% [markdown]
# #### <a id='toc2_4_3_8_'></a>[Decision Tree - Feature Engineered](#toc0_)

# %% [markdown]
# ##### <a id='toc2_4_3_8_1_'></a>[Splitting the Data](#toc0_)

# %% [markdown]
# Isolate the target variable and features.

# %%
y = df2['left']

X = df2.drop('left', axis=1)

# %% [markdown]
# Split the data into training, validation and test sets in a 60/20/20 split while stratifying using y.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
X_tr, X_val, y_tr, y_val = train_test_split(X_train, y_train, test_size=0.25, stratify=y_train, random_state=42)

# %%
print(X_tr.shape)
print(y_tr.shape)
print(X_val.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (7194, 17)
# (7194,)
# (2398, 17)
# (2398,)
# (2399, 17)
# (2399,)

# %% [markdown]
# A Decision Tree Classifier will be instantiated and Hyperparameter Tuned and Cross-Validated using GridSearch as to find the best Model Parameters.

# %%
tree_fe = DecisionTreeClassifier(random_state=42)

cv_params = {'max_depth': [2, 4, 5, 6, 8, 10, 15, 20, 30, 40, 50],
             'min_samples_leaf': [2, 5, 10, 20, 50],
             'min_samples_split': [2, 3, 4, 5, 6]}

scoring = ['accuracy', 'precision', 'recall', 'f1', 'roc_auc']

tree_fe_cv = GridSearchCV(tree_fe, cv_params, scoring=scoring, cv=5, refit='recall')

# %%
# %%time
tree_fe_cv.fit(X_tr, y_tr)
# Out:
# CPU times: total: 24.5 s
# Wall time: 24.8 s
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42),
#              param_grid={'max_depth': [2, 4, 5, 6, 8, 10, 15, 20, 30, 40, 50],
#                          'min_samples_leaf': [2, 5, 10, 20, 50],
#                          'min_samples_split': [2, 3, 4, 5, 6]},
#              refit='recall',
#              scoring=['accuracy', 'precision', 'recall', 'f1', 'roc_auc'])

# %% [markdown]
# ##### <a id='toc2_4_3_8_2_'></a>[Best Parameters](#toc0_)

# %%
tree_fe_cv.best_params_
# Out:
# {'max_depth': 6, 'min_samples_leaf': 2, 'min_samples_split': 2}

# %% [markdown]
# ##### <a id='toc2_4_3_8_3_'></a>[Best Score](#toc0_)

# %%
tree_fe_cv.best_score_
# Out:
# np.float64(0.9029288702928872)

# %% [markdown]
# The best score that the Model achieved out of the GridSearch was 0.90

# %% [markdown]
# ##### <a id='toc2_4_3_8_4_'></a>[GridSearchCV Evaluation Metric Results](#toc0_)

# %% [markdown]
# Use `make_results()` to get all the evaluation metric scores from the GridSearch

# %%
tree_fe_cv_results = make_results('Decision Tree FE CV', tree_fe_cv, 'recall')
results = pd.concat([tree_fe_cv_results, results])
results
# Out:
#                  model  precision    recall        F1  accuracy       auc
# 0  Decision Tree FE CV   0.821845  0.902929  0.860018  0.951070  0.956734
# 0     Decision Tree CV   0.913655  0.913808  0.913306  0.971226  0.969794
# 0     Random Forest CV   0.986504  0.908787  0.945811  0.982763  0.974068
# 0               XGB CV   0.965909  0.911297  0.937448  0.979844  0.983030

# %% [markdown]
# **Insights**

# %% [markdown]
# The Feature Engineered Decision Tree achieves a good performance with a Recall of 0.90, Accuracy of 0.95 and a ROC AUC of 0.96, but its Precision and F1-Score are notably lower than the original Tuned Decision Tree and is clearly below the Random Forest and XGBoost Models. Therefore, this indicates that while the Feature Engineering did not break the Model, the ensemble Models still deliver the strongest and most balanced performance and thereby remain as better candidates for the final solution.

# %% [markdown]
# ##### <a id='toc2_4_3_8_5_'></a>[Decision Tree - Featured Engineered - Prediction Performance Scores](#toc0_)

# %% [markdown]
# The `get_scores()` function can be used to get the evaluation scores from the Decision Tree's predictions.

# %%
tree_fe_cv_val_scores = get_scores('Decision Tree FE CV Val', tree_fe_cv, X_val, y_val)
val_scores = pd.concat([tree_fe_cv_val_scores, val_scores])
val_scores
# Out:
#                      model  precision    recall        f1  accuracy       AUC
# 0  Decision Tree FE CV Val   0.787746  0.904523  0.842105  0.943703  0.928011
# 0     Decision Tree CV Val   0.925000  0.929648  0.927318  0.975813  0.957324
# 0     Random Forest CV Val   0.989276  0.927136  0.957198  0.986239  0.962568
# 0               XGB CV Val   0.968170  0.917085  0.941935  0.981234  0.955543

# %% [markdown]
# **Insights**

# %% [markdown]
# The Feature Engineered Decision Tree predictions on the validation set shows a decent performance, with a Precision of 0.79, Recall of 0.90, F1-Score of 0.84, overall Accuracy of 0.94 and a ROC AUC of 0.93, but it is clearly weaker than the Tuned Standard Decision Tree, Random Forest and XGBoost. Its higher Recall but notably lower Precision indicates there are more false alarms, and therefore it is not competitive with the ensemble Models as a final choice.

# %% [markdown]
# #### <a id='toc2_4_3_9_'></a>[Random Forest - Feature Engineered](#toc0_)

# %% [markdown]
# `GridSearchCV` will be used in order to Hyperparameter Tune and Cross-Validate the Model in order to find the Random Forests best parameters.

# %%
rf_fe = RandomForestClassifier(random_state=42)

cv_params = {'max_depth': [2, 3, 5, None],
             'min_samples_leaf': [1, 2, 5, 10],
             'min_samples_split': [2, 4, 5, 6],
             'max_features': [2, 4, 5],
             'n_estimators': [50, 75, 100, 200, 300, 500]}

scoring = ['accuracy', 'precision', 'recall', 'f1', 'roc_auc']

rf_fe_cv = GridSearchCV(rf_fe, cv_params, scoring=scoring, cv=5, refit='recall')

# %%
# %%time
rf_fe_cv.fit(X_tr, y_tr)

# %% [markdown]
# Lets save it as a pickle

# %%
write_pickle(path, rf_fe_cv, 'rf_fe_cv')

# %%
rf_fe_cv = read_pickle(path, 'rf_fe_cv')

# %% [markdown]
# ##### <a id='toc2_4_3_9_1_'></a>[Best Parameters](#toc0_)

# %%
rf_fe_cv.best_params_
# Out:
# {'max_depth': None,
#  'max_features': 5,
#  'min_samples_leaf': 5,
#  'min_samples_split': 2,
#  'n_estimators': 500}

# %% [markdown]
# ##### <a id='toc2_4_3_9_2_'></a>[Best Score](#toc0_)

# %%
rf_fe_cv.best_score_
# Out:
# np.float64(0.8728033472803347)

# %% [markdown]
# The best Recall score of 0.87 was achieved by the best Model from the GridSearch.

# %% [markdown]
# ##### <a id='toc2_4_3_9_3_'></a>[GridSearchCV Evaluation Metric Results](#toc0_)

# %% [markdown]
# Using `make_results()` to get the evaluation metric results from the GridSearch of the best Model.

# %%
rf_fe_cv_results = make_results('Random Forest FE CV', rf_fe_cv, 'recall')
results = pd.concat([rf_fe_cv_results, results])
results
# Out:
#                  model  precision    recall        F1  accuracy       auc
# 0  Random Forest FE CV   0.907709  0.872803  0.889561  0.964137  0.967618
# 0  Decision Tree FE CV   0.821845  0.902929  0.860018  0.951070  0.956734
# 0     Decision Tree CV   0.913655  0.913808  0.913306  0.971226  0.969794
# 0     Random Forest CV   0.986504  0.908787  0.945811  0.982763  0.974068
# 0               XGB CV   0.965909  0.911297  0.937448  0.979844  0.983030

# %% [markdown]
# **Insights**

# %% [markdown]
# The Feature Engineered Random Forest Model shows a strong but more conservative performance on the training set with a Precision of 0.91, Recall of 0.87, F1-Score of 0.89, Accuracy of 0.96 and a ROC AUC of 0.97. Compared with the earlier Random Forest and XGBoost Models, these scores are slightly lower but still higher than the Feature Engineered Decision Tree. This therefore suggests that by removing/reshaping the potential leakage features, this has reduced overfitting while also preserving the Random Forest as a robust top runner.

# %% [markdown]
# ##### <a id='toc2_4_3_9_4_'></a>[Random Forest - Feature Engineered - Prediction Performance Scores](#toc0_)

# %% [markdown]
# Use `get_scores()` function in order to get the evaluation scores from the Random Forest Model.

# %%
rf_fe_cv_val_scores = get_scores('Random Forest FE CV Val', rf_fe_cv, X_val, y_val)
val_scores = pd.concat([rf_fe_cv_val_scores, val_scores])
val_scores
# Out:
#                      model  precision    recall        f1  accuracy       AUC
# 0  Random Forest FE CV Val   0.922460  0.866834  0.893782  0.965805  0.926167
# 0  Decision Tree FE CV Val   0.787746  0.904523  0.842105  0.943703  0.928011
# 0     Decision Tree CV Val   0.925000  0.929648  0.927318  0.975813  0.957324
# 0     Random Forest CV Val   0.989276  0.927136  0.957198  0.986239  0.962568
# 0               XGB CV Val   0.968170  0.917085  0.941935  0.981234  0.955543

# %% [markdown]
# **Insights**

# %% [markdown]
# The Feature Engineered Random Forest Model remains the strongest Model on the validation set, with high Precision of 0.92, solid Recall of 0.87, F1-Score of 0.89, Accuracy of 0.97 and ROC AUC of 0.93, thereby outperforming both the Decision Tree variants and the original Random Forest/XGBoost baselines. The slight drop from the earlier and suspiciously high scores, combined with the consistently strong performance, hereby suggests that by removing/reshaping the potential leakage features it has produced a more realistic and reliable Model for predicting who is likely to leave.

# %% [markdown]
# #### <a id='toc2_4_3_10_'></a>[XGBoost - Feature Engineered](#toc0_)

# %% [markdown]
# `GridSearchCV` will be used in order to Hyperparameter Tune and Cross-Validate the Model in order to find the XGBoost Model's best parameters.

# %%
xgb_fe = XGBClassifier(objective='binary:logistic', random_state=42)

cv_params = {'max_depth': [4, 5, 10, None],
             'min_child_weight': [4, 8, 10],
             'learning_rate': [0.1, 0.2, 0.3],
             'n_estimators': [75, 100, 125],
             'colsample_bytree': [0.25, 0.5, 0.75]}

scoring = ['accuracy', 'precision', 'recall', 'f1', 'roc_auc']

xgb_fe_cv = GridSearchCV(xgb_fe, cv_params, scoring=scoring, cv=5, refit='recall')

# %%
# %%time
xgb_fe_cv.fit(X_tr, y_tr)

# %% [markdown]
# Let's save it as a pickle

# %%
write_pickle(path, xgb_fe_cv, 'xgb_fe_cv')

# %%
xgb_fe_cv = read_pickle(path, 'xgb_fe_cv')

# %% [markdown]
# ##### <a id='toc2_4_3_10_1_'></a>[Best Parameters](#toc0_)

# %%
xgb_fe_cv.best_params_
# Out:
# {'colsample_bytree': 0.75,
#  'learning_rate': 0.1,
#  'max_depth': 4,
#  'min_child_weight': 4,
#  'n_estimators': 75}

# %% [markdown]
# ##### <a id='toc2_4_3_10_2_'></a>[Best Score](#toc0_)

# %%
xgb_fe_cv.best_score_
# Out:
# np.float64(0.881171548117155)

# %% [markdown]
# The best Model from the GridSearch achieved a Recall score of 0.88

# %% [markdown]
# ##### <a id='toc2_4_3_10_3_'></a>[GridSearchCV Evaluation Metric Results](#toc0_)

# %% [markdown]
# Let's use the `make_results()` function to get all the evaluation metric results from the GridSearch

# %%
xgb_fe_cv_results = make_results('XGB FE CV', xgb_fe_cv, 'recall')
results = pd.concat([xgb_fe_cv_results, results])
results
# Out:
#                  model  precision    recall        F1  accuracy       auc
# 0            XGB FE CV   0.903327  0.881172  0.891765  0.964554  0.972083
# 0  Random Forest FE CV   0.907709  0.872803  0.889561  0.964137  0.967618
# 0  Decision Tree FE CV   0.821845  0.902929  0.860018  0.951070  0.956734
# 0     Decision Tree CV   0.913655  0.913808  0.913306  0.971226  0.969794
# 0     Random Forest CV   0.986504  0.908787  0.945811  0.982763  0.974068
# 0               XGB CV   0.965909  0.911297  0.937448  0.979844  0.983030

# %% [markdown]
# **Insights**

# %% [markdown]
# The Featrure Engineered XGBoost Model delivers a string Cross-Validated performance with a Precision of 0.90, Recall of 0.88, F1-Score of 0.89, Accuracy of 0.096 and a ROC AUC of 0.97, thereby remaining competitive with the earlier Tree-based Models but at a slightly more realistic level than the pre-Feature Engineering results. This drop, combined with the still high ROC AUC, suggests that by removing the potential leakage it has produced a more reliable estimate of XGBoost's true capability without the inflated scores as seen previously.

# %% [markdown]
# ##### <a id='toc2_4_3_10_4_'></a>[XGBoost - Feature Engineered - Predictive Performance Scores](#toc0_)

# %% [markdown]
# Now let's use the `get_scores()` function to get the evaluation scores from the XGBoost Model on the validation set.

# %%
xgb_fe_cv_val = get_scores('XGB FE CV Val', xgb_fe_cv, X_val, y_val)
val_scores = pd.concat([xgb_fe_cv_val, val_scores])
val_scores
# Out:
#                      model  precision    recall        f1  accuracy       AUC
# 0            XGB FE CV Val   0.900510  0.886935  0.893671  0.964971  0.933717
# 0  Random Forest FE CV Val   0.922460  0.866834  0.893782  0.965805  0.926167
# 0  Decision Tree FE CV Val   0.787746  0.904523  0.842105  0.943703  0.928011
# 0     Decision Tree CV Val   0.925000  0.929648  0.927318  0.975813  0.957324
# 0     Random Forest CV Val   0.989276  0.927136  0.957198  0.986239  0.962568
# 0               XGB CV Val   0.968170  0.917085  0.941935  0.981234  0.955543

# %% [markdown]
# **Insights**

# %% [markdown]
# The Feature Engineered XGBoost Model maintains a strong but more realistic performance on the validation set, with a Precision of 0.90, Recall of 0.89, F1-Score of 0.89, Accuracy of 0.96 and a ROC AUC of 0.93. After reducing potential leakage via Feature Engineering, it's scores are now aligned with, althought slightly below, the best Random Forest Model results. Therefore, suggesting that the Model generalises well without relying on overly informative signals from the orignal features.

# %% [markdown]
# #### <a id='toc2_4_3_11_'></a>[Champion Model](#toc0_)

# %% [markdown]
# The champion Model for predicting employee turnover at Salifort Motors is the Feature Engineered Random Forest Classifier. This is because the Model delivers consistently strong validation performance with a high Recall, F1-Score, Accuracy and ROC AUC even after removing the potential leakage, which in turn shows that its predictions are robust rather than being artificially inflated. Compared with the XGBoost Model, the Random Forest Model is less prone to overfitting and hyperparameter sensitivity, is more easier to interpret with its feature-level importance and partial dependence being more straightforward and it avoids the added risks of GBMs such as difficulty with extrapolation and black-box model behaviour. Crucially, the Random Forest Model is far more explainable and so for HR, Legal and Senior Leadership we can clearly show which factors drive risk scores and also justify decisions in plain language, thereby supporting fair employment practices, auditability and trust. This balance of accuracy, stability and explainability therefore makes the Feature Engineered Random Forest Classifier the most suitable choice for Salifort's Stakeholders.

# %% [markdown]
# ##### <a id='toc2_4_3_11_1_'></a>[Evaluation of Champion Model on Test Set](#toc0_)

# %% [markdown]
# Now we will use the champion Model on the test set in order to make predictions and from them compute evaluation metrics. The champion Model is the Feature Engineered Random Forest Classifier (`rf_fe_cv`)

# %% [markdown]
# ##### <a id='toc2_4_3_11_2_'></a>[Champion Model - Test Set - Prediction Performance Scores](#toc0_)

# %% [markdown]
# Using the `get_scores()` function on the test set

# %%
rf_fe_cv_test = get_scores('Random Forest FE CV Test', rf_fe_cv, X_test, y_test)
scores = pd.concat([rf_fe_cv_test, val_scores])
scores
# Out:
#                       model  precision    recall        f1  accuracy       AUC
# 0  Random Forest FE CV Test   0.909326  0.881910  0.895408  0.965819  0.932209
# 0             XGB FE CV Val   0.900510  0.886935  0.893671  0.964971  0.933717
# 0   Random Forest FE CV Val   0.922460  0.866834  0.893782  0.965805  0.926167
# 0   Decision Tree FE CV Val   0.787746  0.904523  0.842105  0.943703  0.928011
# 0      Decision Tree CV Val   0.925000  0.929648  0.927318  0.975813  0.957324
# 0      Random Forest CV Val   0.989276  0.927136  0.957198  0.986239  0.962568
# 0                XGB CV Val   0.968170  0.917085  0.941935  0.981234  0.955543

# %% [markdown]
# **Insights**

# %% [markdown]
# The Feature Engineered Random Forest Model, which is the champion Model, generalises well to the unseen test set by achieving a Precision of 0.91, Recall of 0.88, F1-Score of 0.90, Accuracy of 0.97 and a ROC AUC of 0.93. These strong and balanced scores, which were obtained after removing the potential leakage via Feature Engineering, hereby confirms that the Model reliably identifies at risk employees without overfitting and it continues to outperform or match the more complex alternatives, thereby reinforcing it as the right and trustworthy choice for Salifort Motors.

# %% [markdown]
# ##### <a id='toc2_4_3_11_3_'></a>[Confusion Matrix](#toc0_)

# %% [markdown]
# Let's compute a Confusion Matrix of the Feature Engineered Random Forest Model's predictions

# %%
test_preds = rf_fe_cv.best_estimator_.predict(X_test)

# %%
cm = confusion_matrix(y_test, test_preds, labels=rf_fe_cv.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=rf_fe_cv.classes_)
disp.plot()
plt.title("Random Forest FE CV - Test Set")
# Out:
# Text(0.5, 1.0, 'Random Forest FE CV - Test Set')

# %% [markdown]
# Let's also make a Classification Report

# %%
target_labels = ['Predicted would not leave', 'Predicted would leave']
print(classification_report(y_test, test_preds, target_names=target_labels))
# Out:
#                            precision    recall  f1-score   support
#
# Predicted would not leave       0.98      0.98      0.98      2001
#     Predicted would leave       0.91      0.88      0.90       398
#
#                  accuracy                           0.97      2399
#                 macro avg       0.94      0.93      0.94      2399
#              weighted avg       0.97      0.97      0.97      2399

# %% [markdown]
# **Insights**

# %% [markdown]
# **Confusion Matrix**
#
# * **True Negatives = 1966** Most of the employees who stayed were correctly predicted as staying.
# * **False Positives = 35** A small number of employees who stayed were incorrectly classified as leaving.
# * **False Negatives = 47** A minority of employees who left were missclassified as those who would stay.
# * **True Positives = 351** Majority of the employees who left were correctly identified.
#
# **Classification Report**
#
# * **Predicted would not leave** - Precision = 0.98, Recall = 0.98, F1-Score = 0.98
# * **Predicted would leave** - Precision = 0.91, Recall = 0.88, F1-Score = 0.90
# * **Overall Accuracy** - 0.97 The Model correctly classifies 97% of cases.
#
# The Feature Engineered Random Forest champion Model demonstrates a strong and reliable performance on the unseen test set. It correctly identifies 1,966 Stayers and 351 Leavers with only 35 false alarms and 47 missed leavers, with a Precision of 0.98/0.91, Recall of 0.98/0.88 for Stayer/Leaver with an overall accuracy of 0.97. After removing the potential leakage and simplifying features, the Model still achieves a high Recall for Leavers all while remaining interpretable as its tree-based structure and feature importances can be clearly explained to HR, Legal and Leadership, thereby making it both effective and suitable for a trustworthy deployment at Salifort Motors.

# %% [markdown]
# #### <a id='toc2_4_3_12_'></a>[Feature Importance](#toc0_)

# %% [markdown]
# Now we will plot the Feature Importance of the champion Model, which is the Feature Engineered Random Forest Model.

# %% [markdown]
# **Top 10 Features**

# %%
importances = rf_fe_cv.best_estimator_.feature_importances_

# Indicies of the top 10 features
indicies = np.argpartition(rf_fe_cv.best_estimator_.feature_importances_, -10)[-10:]

# Column labels of the top 10 features
features = X_test.columns[indicies]

# Filter the `importances` to only consist of the top 10 feature importances.
importances = importances[indicies]
feat_imp = pd.DataFrame({'Feature': features,
                         'Importance': importances})
feat_imp = feat_imp.sort_values(by='Importance', ascending=False)
fig = plt.figure(figsize=(10,6))
sns.barplot(x='Importance', y='Feature', data=feat_imp)
plt.title("Random Forest FE CV Feature Importance")
plt.xlabel("Importance")
plt.ylabel("Feature")
plt.show()

# %% [markdown]
# **Insights**

# %% [markdown]
# The Feature Engineered Random Forest Model highlights a clear set of drivers behind employees leaving Salifort Motors. The number of projects (`number_project`) is the strongest predictor, followed by `tenure` and `last_evaluation`, thereby indicating that the workload mix, time at the company and performance signals are central to employee turnover risk. The engineered feature `overworked` which is a flag of high monthly hours, also plays a meaningful role, thereby reinforcing that a sustained heavy workload contributes to employees leaving. `salary` and `work_accident` have smaller but non-negligible effects, while the `department` dummies add very little, which suggests that how people work such as workload, tenure, performance and hours, matters far more than where they work in the organisation.

# %% [markdown]
# ## <a id='toc2_5_'></a>[PACE: Execute Stage](#toc0_)
# - Interpret model performance and results
# - Share actionable steps with stakeholders

# %% [markdown]
# ✏
# ## <a id='toc2_6_'></a>[Recall evaluation metrics](#toc0_)
#
# - **AUC** is the area under the ROC curve; it's also considered the probability that the model ranks a random positive example more highly than a random negative example.
# - **Precision** measures the proportion of data points predicted as True that are actually True, in other words, the proportion of positive predictions that are true positives.
# - **Recall** measures the proportion of data points that are predicted as True, out of all the data points that are actually True. In other words, it measures the proportion of positives that are correctly classified.
# - **Accuracy** measures the proportion of data points that are correctly classified.
# - **F1-score** is an aggregation of precision and recall.

# %% [markdown]
# 💭
# ### <a id='toc2_6_1_'></a>[Reflect on these questions as you complete the executing stage.](#toc0_)
#
# - What key insights emerged from your model(s)?
# - What business recommendations do you propose based on the models built?
# - What potential recommendations would you make to your manager/company?
# - Do you think your model could be improved? Why or why not? How?
# - Given what you know about the data and the models you were using, what other questions could you address for the team?
# - What resources do you find yourself using as you complete this stage? (Make sure to include the links.)
# - Do you have any ethical considerations in this stage?

# %% [markdown]
# ## <a id='toc2_7_'></a>[Step 4. Results and Evaluation](#toc0_)
# - Interpret model
# - Evaluate model performance using metrics
# - Prepare results, visualizations, and actionable steps to share with stakeholders

# %% [markdown]
# ### <a id='toc2_7_1_'></a>[Summary of Model Results](#toc0_)

# %% [markdown]
# **Logistic Regression**

# %% [markdown]
# The Logistic Regression Model works reasonably as a baseline but it is not strong enough for Salifort's needs. This is because it achieved an overall Accuracy of 83% and performs well for employees who stay (True Negatives = 1752, Precision 0.86, Recall = 0.94, F1-Score = 0.90), but it struggles badly on employees who leave (True Positives = 92 vs 284 False Negatives, Precision = 0.46, Recall - 0.24, F1-Score = 0.32). This means that most of the high risk leavers are missed and so the Model is heavily biased towards predicting employees who will stay and is therefore unsuitable as the primary turnover prediction tool.

# %% [markdown]
# **Tree-Based Machine Learning**

# %% [markdown]
# All the Tree-Based Models, their performance on predicting employee turnover was consistently strong and clearly superior to the Logistic Regression baseline. The initial Decision Tree, Random Forest and XGBoost Classifiers all achieved high evaluation metric scores, such as the overall Accuracy being in the mid nineties plus range, thereby indicating that the Non-Linear, interaction-aware Models captured the underlying patterns in satisfaction, tenure, workload, evaluation and other related factors much better than a Linear Model.
#
# The introduction of Feature Engineering helped stress-test for potential leakage and check robustness. The Feature Engineered Decision Tree lost some performance and stability, which suggests it was more sensitive and prone to overfitting. In comparison, the Feature Engineered Random Forest and XGBoost Models maintained a high Precision, Recall, F1-Score and AUC on both the validation and test sets, thereby confirming that the key patterns generalise. Between them, the Feature Engineered Random Forest Model was selected as the champion Model and it delivered an excellent test performance, with 97% Accuracy and 0.93+ ROC AUC as well as a strong Recall for leavers. The champion Model remained relatively stable across Cross-Validation/Validation/Test splits and is also more interpretable than GBMs like XGBoost, which are harder to explain, more complex to tune and more prone to overfitting.

# %% [markdown]
# ### <a id='toc2_7_2_'></a>[Conclusion, Recommendations, Next Steps](#toc0_)

# %% [markdown]
# **Conclusion**
#
# In conclusion, throughout this project it has been shown that employee turnover at Salifort Motors is predictable and actionable. EDA was conducted on the data and from this insights were gained such as factors like workload, satisfaction, tenure and performance patterns are meaningfully linked to employees leaving, and these insights were also used to help guide the Feature Engineering and Model design. A baseline Model of a Logistic Regression was conducted in order to see how well it classifies the employees. The Logistic Regression Model performed well for employees who would stay at Salifort's but bad on the employees who would leave, which in our case is the opposite to our objective. Therefore, the Logistic Regression Model was deemed unsuitable for the task of predicting employee turnover and Tree-Based Modelling was pursued. These Tree-Based Models vastly outperformed the Logistic Regression Model, with there being a Decision Tree, Random Forest and XGBoost Classifiers Modelled. These Models GridSearch evaluation metrics results were then evaluated and compared, along with the evaluation metric results from the Model's predictions on the validation set. Afterwards, due to skeptically high results from potential data leakage, Feature Engineering was then conducted and the three Models were modelled, evaluated and compared with the new Feature Engineered Data. From this, a champion Model was then selected, this being the Feature Engineered Random Forest Classifer, as it delivers strong and stable performance on unseen data while remaining interpretable enough for HR, Legal and Leadership to understand and trust. The champion Model was then evaluated on the unseen test set where it displayed an excellent classification performance with strong metrics such as 97% overall Accuracy, 0.93 ROC AUC and a strong Recall for employees who left. The champion Model remained steadfast accross all the evaluations and is more interpretable than GBMs such as XGBoost whose predictions are harder to explain, struggle with extrapolation and are prone to overfitting if too many hyperparameters are tuned. The champion Model was then used to generate a feature importance plot where it highlighted that the risk of leaving is driven primarily by the number of project, mid-range tenure, signals of being overworked and high performance without progression, with salary and accidents playing smaller roles. Overall the solution provides Salifort Motors with a robust, ethically deployable tool to proactively identify and support at-risk employees rather than reactively manage unexpected departures.

# %% [markdown]
# **Recommendations**
#
# 1. **Workload and Overwork**
#
#    Salifort Motors should set clear limits on projects and working hours, regularly review employees who appear overworked and adjust the workloads or provide recovery time where needed.
# 2. **Career Growth and Mid-Tenure Risk**
#
#    The company should focus on employees with a 2-5 years of tenure by offering clear development paths, targeted growth discussions and timely promotion oppourtunities.
# 3. **High Performers Under Strain**
#
#    HR and managers should proactively identify employees with high evaluations, heavy workloads and no recent promotion and offer these employees recognition, rewards, role expansions or internal mobility before they decide to leave.
# 4. **Compensation and Recognition**
#
#    The compensation and recognition practices should be reviewed using Model insights as to ensure that pay and rewards fairly reflect performance and responsibilities in higher-risk roles and segments.
# 5. **Responsible Use and Governance**
#
#    The prediction Model should be used as a supportive decision tool with transparent documentation, bias checks and governance in place as to ensure that the outputs guide retention actions and do not directly drive punitive decisions.

# %% [markdown]
# **Next Steps**
#
# 1. **Deployment**
#
#    Salifort Motors should deploy the Feature Engineered Random Forest Model into a simple retention dashboard that surfaces the employee-level risk scores and the top contributing factors such as the number of projects, tenure, evaluation and overworked flag. This dashboard should only be accessible to HR and approved managers with a clear guidance on how to read and respond to the scores. Each view should avoid exposing any unnecessary personal data while still giving enough context to support informed and supportive conversations.
#
# 2. **Threshold and Calibration**
#
#    The team should select decision thresholds that prioritise catching likely leavers while also keeping False Positives at a manageable level which thereby explicity reflects the higher cost of missed leavers. These thresholds should be based on validation/test results and be revisited regularly as more outcomes are observed. Wherever possible, probabilities should be calibrated so that a given score corresponds to a consistent, interpretable level of risk.
#
# 3. **Pilot and Rollout**
#
#    Salifort should first run a structured pilot in a small number of departments as to test how well the Model driven interventions work in practice. During the pilot, HR and managers should log the actions taken such as workload changes and career discussions and also track the outcomes such as reductions in people leaving, manager feedback and employee sentiment. If the pilot shows a positive impact and responsible use, the solution can then be rolled out more widely with minor adjustments based on real world learning.
#
# 4. **Monitoring and Governance**
#
#    The Model should be monitored on an ongoing basis for performance via Precision, Recall, ROC AUC and stability across time with alerts if metrics degrade. Salifort must regularly check results by segment (department, tenure band, role level) in order to detect and address any unfair patterns. Clear policies, documentation, approval workflows and audit logs should be in place so that HR, Legal and Leadership can see how the predictions are generated, accessed and used.
#
# 5. **Enhancements**
#
#    Over time the team should incorporate additional high-value feature such as internal mobility activity, training participation, manager changes and engagement trends as to improve the accuracy and context while maintaining privacy safeguards. The Model should be retrained periodically on updated data in order to reflect current conditions, policies and workforce dynamics. Salifort can also compliment the Random Forest with explainability tools such as SHAP and simple rule-based checks in order to make insights even clearer and support continuous improvement of retention strategies.

# %% [markdown]
# **Congratulations!** You've completed this lab. However, you may not notice a green check mark next to this item on Coursera's platform. Please continue your progress regardless of the check mark. Just click on the "save" icon at the top of this notebook to ensure your work has been logged.

# %% [markdown]
# ## <a id='toc2_8_'></a>[Appendix](#toc0_)

# %% [markdown]
# ### <a id='toc2_8_1_'></a>[GridSearch Results](#toc0_)

# %%
results
# Out:
#                  model  precision    recall        F1  accuracy       auc
# 0            XGB FE CV   0.903327  0.881172  0.891765  0.964554  0.972083
# 0  Random Forest FE CV   0.907709  0.872803  0.889561  0.964137  0.967618
# 0  Decision Tree FE CV   0.821845  0.902929  0.860018  0.951070  0.956734
# 0     Decision Tree CV   0.913655  0.913808  0.913306  0.971226  0.969794
# 0     Random Forest CV   0.986504  0.908787  0.945811  0.982763  0.974068
# 0               XGB CV   0.965909  0.911297  0.937448  0.979844  0.983030

# %%
results.to_csv('GridSearchCV Results.csv', index=False)

# %% [markdown]
# ### <a id='toc2_8_2_'></a>[GridSearch Results - Feature Engineered Only](#toc0_)

# %%
results_fe = results[results['model'].str.contains('FE CV')]
results_fe
# Out:
#                  model  precision    recall        F1  accuracy       auc
# 0            XGB FE CV   0.903327  0.881172  0.891765  0.964554  0.972083
# 0  Random Forest FE CV   0.907709  0.872803  0.889561  0.964137  0.967618
# 0  Decision Tree FE CV   0.821845  0.902929  0.860018  0.951070  0.956734

# %%
results_fe.to_csv('GridSearchCV Results Feature Engineered.csv', index=False)

# %% [markdown]
# ### <a id='toc2_8_3_'></a>[Prediction Performance Results](#toc0_)

# %%
scores
# Out:
#                       model  precision    recall        f1  accuracy       AUC
# 0  Random Forest FE CV Test   0.909326  0.881910  0.895408  0.965819  0.932209
# 0             XGB FE CV Val   0.900510  0.886935  0.893671  0.964971  0.933717
# 0   Random Forest FE CV Val   0.922460  0.866834  0.893782  0.965805  0.926167
# 0   Decision Tree FE CV Val   0.787746  0.904523  0.842105  0.943703  0.928011
# 0      Decision Tree CV Val   0.925000  0.929648  0.927318  0.975813  0.957324
# 0      Random Forest CV Val   0.989276  0.927136  0.957198  0.986239  0.962568
# 0                XGB CV Val   0.968170  0.917085  0.941935  0.981234  0.955543

# %%
scores.to_csv('Prediction Performance Results.csv', index=False)

# %% [markdown]
# ### <a id='toc2_8_4_'></a>[Prediction Performance Results - Feature Engineered Only](#toc0_)

# %%
scores_fe = scores[scores['model'].str.contains('FE CV')]
scores_fe.sort_values(by='model', ascending=False)
scores_fe
# Out:
#                       model  precision    recall        f1  accuracy       AUC
# 0  Random Forest FE CV Test   0.909326  0.881910  0.895408  0.965819  0.932209
# 0             XGB FE CV Val   0.900510  0.886935  0.893671  0.964971  0.933717
# 0   Random Forest FE CV Val   0.922460  0.866834  0.893782  0.965805  0.926167
# 0   Decision Tree FE CV Val   0.787746  0.904523  0.842105  0.943703  0.928011

# %%
scores_fe.to_csv('Prediction Performance Scores FE.csv', index=False)

# %% [markdown]
# ### <a id='toc2_8_5_'></a>[Predictions from Test Set](#toc0_)

# %%
test_preds_df = pd.DataFrame({'employee_id': X_test.index,
                              'left': test_preds})
test_preds_df
# Out:
#       employee_id  left
# 0           11555     0
# 1              27     1
# 2            5890     0
# 3            9098     0
# 4             239     1
# ...           ...   ...
# 2394         9158     0
# 2395         8190     0
# 2396         4911     0
# 2397        11196     0
# 2398         1651     1
#
# [2399 rows x 2 columns]

# %%
test_preds_df.to_csv('Employee Turnover Predictions.csv', index=False)
